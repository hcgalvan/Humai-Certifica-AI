# %% [markdown]
#  Esta notebook tomará un video, moviendo mano de la derecha y luego la izquierda, que vas a grabar y luego etiquetar. Paso siguiente, generas un modelo, para luego utilizar como predicción.

# %%
# !pip install mediapipe opencv-python

# %%
import cv2
import mediapipe as mp
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# Capturar video: es solo prueba de que funciona. No realiza mas que mostrar.
# Para salir pulsa la tecla "q"
cap = cv2.VideoCapture(0)
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()

        #Recolorear 
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Detectar
        results = pose.process(image) 
        
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, 
                            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                            )
        
        cv2.imshow('Raw Webcam Feed', image)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Grabar Video

# %%
# import time
VIDEO_PATH = 'manos.avi'
EXPORT_PATH = 'manos.csv'
MODEL_PATH = 'manos.pkl'

# %%
#1. Grabar Video. Para terminar de grabar pulsa la tecla "q"
cap = cv2.VideoCapture(0)
alto = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
ancho = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps = cap.get(cv2.CAP_PROP_FPS)

videoWriter = cv2.VideoWriter(VIDEO_PATH, cv2.VideoWriter_fourcc('P','I','M','1'), fps, (int(ancho), int(alto)))

# time.sleep(5)

while cap.isOpened():
    ret, frame = cap.read()
    
    try:
        cv2.imshow('Imagen', frame)
        videoWriter.write(frame)
    except Exception as e:
        break
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
videoWriter.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Capturar puntos de referencia y exportar a CSV

# %% [markdown]
# Esta sección crea el archivo, colocas los titulos y arma un primera estructura

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
landmarks = ['class']
for val in range(1,33+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks[1:]
# Out:
# ['x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33']

# %%
with open(EXPORT_PATH, mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
def export_landmark(results, action):
    try:
        keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten().tolist()
        keypoints.insert(0, action)

        with open(EXPORT_PATH, mode='a', newline='') as f:
            csv_writer = csv.writer(f, delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
    except Exception as e:
        pass

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.47486090660095215
#   y: 0.2910394072532654
#   z: -1.2571769952774048
#   visibility: 0.9999338388442993
# }
# landmark {
#   x: 0.5055432319641113
#   y: 0.22317907214164734
#   z: -1.1888549327850342
#   visibility: 0.9998621940612793
# }
# landmark {
#   x: 0.5273564457893372
#   y: 0.21984736621379852
#   z: -1.1891331672668457
#   visibility: 0.9998812079429626
# }
# landmark {
#   x: 0.5443103909492493
#   y: 0.21790313720703125
#   z: -1.189330816268921
#   visibility: 0.9998503923416138
# }
# landmark {
#   x: 0.44209569692611694
#   y: 0.23190554976463318
#   z: -1.1940147876739502
#   visibility: 0.9998626708984375
# }
# landmark {
#   x: 0.4218842387199402
#   y: 0.234610453248024
#   z: -1.193172812461853
#   visibility: 0.9998833537101746
# }
# landmark {
#   x: 0.4050838351249695
#   y: 0.23716512322425842
#   z: -1.1936848163604736
#   visibility: 0.9998641014099121
# }
# landmark {
#   x: 0.5765156149864197
#   y: 0.2455269694328308
#   z: -0.7118586301803589
#   visibility: 0.9998740553855896
# }
# landmark {
#   x: 0.3890378177165985
#   y: 0.27088361978530884
#   z: -0.7194270491600037
#   visibility: 0.9999125003814697
# }
# landmark {
#   x: 0.5225153565406799
#   y: 0.3576796352863312
#   z: -1.074211835861206
#   visibility: 0.9999404549598694
# }
# landmark {
#   x: 0.44119754433631897
#   y: 0.3666684925556183
#   z: -1.076674222946167
#   visibility: 0.9999492168426514
# }
# landmark {
#   x: 0.7498148083686829
#   y: 0.618278443813324
#   z: -0.3714819550514221
#   visibility: 0.9989936947822571
# }
# landmark {
#   x: 0.2730715274810791
#   y: 0.6676405072212219
#   z: -0.4727579951286316
#   visibility: 0.9987316131591797
# }
# landmark {
#   x: 0.8731099367141724
#   y: 1.0420722961425781
#   z: -0.33632245659828186
#   visibility: 0.210036039352417
# }
# landmark {
#   x: 0.16651307046413422
#   y: 1.0687800645828247
#   z: -0.453963041305542
#   visibility: 0.3304145634174347
# }
# landmark {
#   x: 0.9421753883361816
#   y: 1.461703896522522
#   z: -0.8574587106704712
#   visibility: 0.04825207218527794
# }
# landmark {
#   x: 0.16454747319221497
#   y: 1.4810360670089722
#   z: -1.0891749858856201
#   visibility: 0.08227308094501495
# }
# landmark {
#   x: 0.9871813058853149
#   y: 1.5761076211929321
#   z: -1.0206124782562256
#   visibility: 0.060867201536893845
# }
# landmark {
#   x: 0.14640776813030243
#   y: 1.594521164894104
#   z: -1.2724413871765137
#   visibility: 0.09173081815242767
# }
# landmark {
#   x: 0.9373477101325989
#   y: 1.5795295238494873
#   z: -1.122427225112915
#   visibility: 0.10879342257976532
# }
# landmark {
#   x: 0.19363698363304138
#   y: 1.5749366283416748
#   z: -1.3893852233886719
#   visibility: 0.15074734389781952
# }
# landmark {
#   x: 0.9067171812057495
#   y: 1.5357290506362915
#   z: -0.9269264340400696
#   visibility: 0.10481106489896774
# }
# landmark {
#   x: 0.21120762825012207
#   y: 1.5303044319152832
#   z: -1.1606471538543701
#   visibility: 0.14098188281059265
# }
# landmark {
#   x: 0.6883980631828308
#   y: 1.5187838077545166
#   z: -0.06156519055366516
#   visibility: 0.0007978422218002379
# }
# landmark {
#   x: 0.3581911325454712
#   y: 1.5377942323684692
#   z: 0.06783336400985718
#   visibility: 0.0006974306306801736
# }
# landmark {
#   x: 0.6904666423797607
#   y: 2.2409894466400146
#   z: -0.1385340392589569
#   visibility: 0.0006796702509745955
# }
# landmark {
#   x: 0.3703789710998535
#   y: 2.258669137954712
#   z: -0.04938014596700668
#   visibility: 0.00019850580429192632
# }
# landmark {
#   x: 0.7010509967803955
#   y: 2.89420223236084
#   z: 0.5063771605491638
#   visibility: 5.559549754252657e-05
# }
# landmark {
#   x: 0.38330429792404175
#   y: 2.91231369972229
#   z: 0.3621247410774231
#   visibility: 1.1707695193763357e-05
# }
# landmark {
#   x: 0.7128610014915466
#   y: 2.998192071914673
#   z: 0.5301141142845154
#   visibility: 4.772594911628403e-05
# }
# landmark {
#   x: 0.38225576281547546
#   y: 3.0247421264648438
#   z: 0.37828510999679565
#   visibility: 2.2490487026516348e-05
# }
# landmark {
#   x: 0.6417702436447144
#   y: 3.1075549125671387
#   z: -0.16478019952774048
#   visibility: 6.297689105849713e-05
# }
# landmark {
#   x: 0.4249841570854187
#   y: 3.0998992919921875
#   z: -0.3521203398704529
#   visibility: 4.881353015662171e-05
# }

# %%
export_landmark(results, 'neutro' )

# %% [markdown]
# ## Etiquetado y grabo con coordenadas
#
# A medida que se mira el video y tenemos las coordenadas, vamos etiquetando manualmente. A medida que lo etiquetamos va guardando en un archivo csv.
# Para equitar pulsa la tecla "d" para derecha y lo mantienes pulsa mientras miras el video la posición. Con tecla "i" para izquierda y lo mantienes pulsado mientras sea esta situación.
# Si ninguna de las dos, posición neutra, pulsa la tecla "n".
# Para salir del video y no produzca error al final, pulsamos la tecla "q".

# %%
cap = cv2.VideoCapture(VIDEO_PATH)    

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recolorear 
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Detectar
        results = pose.process(image) 

        #Recolorear el fondo de la imagen para para renderizar
        image.flags.writeable = True
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        k = cv2.waitKey(1)
        ## export_landmark(results, k)
        ## con las teclas d (100) y u (117) etiqueto en linea
        if k == ord('d'):
            export_landmark(results, 'derecha')
        if k == ord('n'):
            export_landmark(results, 'neutro')            
        if k == ord('i'):
            export_landmark(results, 'izquierda')

        cv2.imshow('Video Grabado', image)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Si queda con error el anterior codigo, lo cerramos con el codigo que sigue.

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Entrenar un modelo usando Scikit Learn

# %%
# !pip install scikit-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(EXPORT_PATH)

# %%
df.head()
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 0   neutro  0.474861  0.291039 -1.257177  0.999934  0.505543  0.223179
# 1  derecha  0.523299  0.328887 -0.750328  0.999917  0.543749  0.282869
# 2  derecha  0.523297  0.328915 -0.749171  0.999919  0.543722  0.282880
# 3  derecha  0.523294  0.328929 -0.753291  0.999921  0.543715  0.282891
# 4  derecha  0.523285  0.328957 -0.755113  0.999923  0.543706  0.282901
#
#          z2        v2        x3  ...       z31       v31       x32       y32  \
# 0 -1.188855  0.999862  0.527356  ...  0.378285  0.000022  0.641770  3.107555
# 1 -0.696762  0.999827  0.555715  ...  0.513417  0.000124  0.569531  2.394774
# 2 -0.696058  0.999830  0.555694  ...  0.514389  0.000121  0.570639  2.395690
# 3 -0.699494  0.999835  0.555686  ...  0.593414  0.000120  0.570600  2.396816
# 4 -0.701451  0.999839  0.555682  ...  0.592471  0.000118  0.569689  2.397805
#
#         z32       v32       x33       y33       z33       v33
# 0 -0.164780  0.000063  0.424984  3.099899 -0.352120  0.000049
# 1 -0.165696  0.000129  0.413164  2.398313 -0.027412  0.000216
# 2 -0.172561  0.000122  0.415964  2.399435 -0.024830  0.000208
# 3 -0.168951  0.000116  0.415539  2.400757  0.049224  0.000203
# 4 -0.158050  0.000110  0.414266  2.401745  0.045434  0.000197
#
# [5 rows x 133 columns]

# %%
df.tail()
# Out:
#          class        x1        y1        z1        v1        x2        y2  \
# 352  izquierda  0.504580  0.336045 -0.733809  0.999982  0.528803  0.290342
# 353  izquierda  0.503865  0.335423 -0.788473  0.999982  0.527666  0.289314
# 354  izquierda  0.503004  0.335355 -0.805317  0.999982  0.526815  0.289126
# 355     neutro  0.501765  0.337490 -1.152842  0.999822  0.524885  0.289562
# 356     neutro  0.501756  0.337670 -1.141416  0.999813  0.524845  0.289593
#
#            z2        v2        x3  ...       z31       v31       x32  \
# 352 -0.680536  0.999961  0.541081  ...  0.081062  0.000096  0.527533
# 353 -0.730365  0.999960  0.540348  ...  0.085479  0.000090  0.526903
# 354 -0.748620  0.999960  0.539839  ...  0.118980  0.000085  0.526771
# 355 -1.096544  0.999609  0.538369  ... -0.009380  0.000231  0.554355
# 356 -1.085809  0.999594  0.538330  ... -0.019890  0.000253  0.554403
#
#           y32       z32       v32       x33       y33       z33       v33
# 352  2.460781 -0.176100  0.000209  0.378894  2.439114 -0.434982  0.000230
# 353  2.462901 -0.153586  0.000206  0.375823  2.441308 -0.446208  0.000223
# 354  2.467142 -0.120499  0.000203  0.374427  2.446508 -0.423895  0.000215
# 355  2.471511 -0.220455  0.000343  0.381342  2.466024 -0.616448  0.000401
# 356  2.470453 -0.239033  0.000365  0.381683  2.464161 -0.622420  0.000435
#
# [5 rows x 133 columns]

# %%
df[df['class']=='derecha']
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 1    derecha  0.523299  0.328887 -0.750328  0.999917  0.543749  0.282869
# 2    derecha  0.523297  0.328915 -0.749171  0.999919  0.543722  0.282880
# 3    derecha  0.523294  0.328929 -0.753291  0.999921  0.543715  0.282891
# 4    derecha  0.523285  0.328957 -0.755113  0.999923  0.543706  0.282901
# 5    derecha  0.523157  0.329015 -0.753363  0.999926  0.543583  0.282910
# ..       ...       ...       ...       ...       ...       ...       ...
# 293  derecha  0.510803  0.333531 -1.212979  0.999851  0.534859  0.288801
# 294  derecha  0.510039  0.333523 -1.161091  0.999841  0.534235  0.288801
# 295  derecha  0.509556  0.333530 -1.148435  0.999830  0.533857  0.288810
# 296  derecha  0.508049  0.333501 -1.184223  0.999825  0.532526  0.288721
# 297  derecha  0.506687  0.333498 -1.170456  0.999818  0.531216  0.288572
#
#            z2        v2        x3  ...       z31       v31       x32  \
# 1   -0.696762  0.999827  0.555715  ...  0.513417  0.000124  0.569531
# 2   -0.696058  0.999830  0.555694  ...  0.514389  0.000121  0.570639
# 3   -0.699494  0.999835  0.555686  ...  0.593414  0.000120  0.570600
# 4   -0.701451  0.999839  0.555682  ...  0.592471  0.000118  0.569689
# 5   -0.699320  0.999845  0.555613  ...  0.571746  0.000117  0.569720
# ..        ...       ...       ...  ...       ...       ...       ...
# 293 -1.149084  0.999701  0.546250  ...  0.125233  0.000245  0.562802
# 294 -1.101189  0.999680  0.545822  ...  0.029692  0.000274  0.547963
# 295 -1.089297  0.999660  0.545537  ...  0.026935  0.000297  0.543714
# 296 -1.126499  0.999655  0.544774  ...  0.023205  0.000357  0.543819
# 297 -1.113760  0.999642  0.543988  ...  0.000084  0.000370  0.544957
#
#           y32       z32       v32       x33       y33       z33       v33
# 1    2.394774 -0.165696  0.000129  0.413164  2.398313 -0.027412  0.000216
# 2    2.395690 -0.172561  0.000122  0.415964  2.399435 -0.024830  0.000208
# 3    2.396816 -0.168951  0.000116  0.415539  2.400757  0.049224  0.000203
# 4    2.397805 -0.158050  0.000110  0.414266  2.401745  0.045434  0.000197
# 5    2.398211 -0.153723  0.000104  0.414127  2.402720  0.025951  0.000191
# ..        ...       ...       ...       ...       ...       ...       ...
# 293  2.466999 -0.139549  0.000234  0.393607  2.461857 -0.498771  0.000390
# 294  2.472805 -0.145325  0.000271  0.377914  2.467140 -0.590251  0.000429
# 295  2.475870 -0.148496  0.000301  0.373572  2.469914 -0.595739  0.000460
# 296  2.476297 -0.201981  0.000362  0.372768  2.471390 -0.588514  0.000568
# 297  2.478201 -0.209895  0.000393  0.373920  2.471792 -0.604527  0.000606
#
# [166 rows x 133 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 44        neutro
# 7        derecha
# 278      derecha
# 327    izquierda
# 90     izquierda
#          ...
# 200    izquierda
# 9        derecha
# 29       derecha
# 184    izquierda
# 261      derecha
# Name: class, Length: 108, dtype: object

# %% [markdown]
# ## Entrenar con el modelo de clasificación de Machine Learning

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    #'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['neutro', 'derecha', 'derecha', 'izquierda', 'izquierda',
#        'izquierda', 'derecha', 'izquierda', 'izquierda', 'derecha',
#        'neutro', 'derecha', 'derecha', 'izquierda', 'izquierda', 'neutro',
#        'izquierda', 'izquierda', 'derecha', 'izquierda', 'neutro',
#        'izquierda', 'izquierda', 'derecha', 'derecha', 'izquierda',
#        'derecha', 'derecha', 'neutro', 'derecha', 'izquierda', 'derecha',
#        'derecha', 'izquierda', 'izquierda', 'izquierda', 'izquierda',
#        'izquierda', 'derecha', 'neutro', 'izquierda', 'izquierda',
#        'derecha', 'derecha', 'neutro', 'izquierda', 'izquierda',
#        'izquierda', 'derecha', 'derecha', 'izquierda', 'izquierda',
#        'derecha', 'izquierda', 'izquierda', 'neutro', 'derecha',
#        'izquierda', 'izquierda', 'derecha', 'izquierda', 'izquierda',
#        'neutro', 'neutro', 'neutro', 'izquierda', 'izquierda', 'derecha',
#        'derecha', 'izquierda', 'neutro', 'neutro', 'derecha', 'derecha',
#        'neutro', 'izquierda', 'izquierda', 'izquierda', 'izquierda',
#        'derecha', 'derecha', 'derecha', 'neutro', 'izquierda', 'derecha',
#        'derecha', 'derecha', 'izquierda', 'derecha', 'izquierda',
#        'izquierda', 'derecha', 'derecha', 'derecha', 'izquierda',
#        'izquierda', 'izquierda', 'izquierda', 'izquierda', 'derecha',
#        'izquierda', 'izquierda', 'izquierda', 'izquierda', 'derecha',
#        'derecha', 'izquierda', 'derecha'], dtype='<U9')

# %% [markdown]
# ## Evaluar y Serializar el modelo

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat),
          precision_score(y_test.values, yhat, average="weighted", pos_label="derecha"),
          recall_score(y_test.values, yhat, average="weighted", pos_label="derecha"))
# Out:
# rc 1.0 1.0 1.0
# rf 0.9814814814814815 0.9836601307189542 0.9814814814814815
# gb 0.9537037037037037 0.9588477366255144 0.9537037037037037
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1396: UserWarning: Note that pos_label (set to 'derecha') is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %%
yhat = fit_models['rf'].predict(X_test)

# %%
yhat[:10]
# Out:
# array(['neutro', 'derecha', 'derecha', 'izquierda', 'izquierda',
#        'izquierda', 'derecha', 'izquierda', 'izquierda', 'derecha'],
#       dtype=object)

# %%
with open(MODEL_PATH, 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # Detectar con el modelo

# %%
with open(MODEL_PATH, 'rb') as f:
    model = pickle.load(f)

# %%
# X = pd.DataFrame([row], columns=landmarks[1:])
# Out:
# array(['up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up'],
#       dtype=object)

# %%
cap = cv2.VideoCapture(0)

# Curl counter variables
counter = 0 
current_stage = None

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Detección de Pose
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Extract landmarks
        try:
            
            row = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten().tolist()
            X = pd.DataFrame([row], columns=landmarks[1:])
            
            body_language_class = model.predict(X)[0]
            
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            if body_language_class or body_language_prob:
                print('predicted')
            else :
                print('prediction error')

            if body_language_class == "derecha" and body_language_prob[body_language_prob.argmax()] >= 0.7:
                current_stage = "derecha"
            elif current_stage=="derecha" and body_language_class=="izquierda" and body_language_prob[body_language_prob.argmax()] >= 0.7:
                current_stage = "izquierda"
                counter +=1
                
            # obtener el estado del box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Mostrar las clases
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Mostrar Probabilidad
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                       , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Mostrar Conteo
            cv2.putText(image, 'COUNT'
                        , (180,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(counter)
                        , (175,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
  
        except Exception as e:
            pass

        cv2.imshow('En vivo sin procesar', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# neutro [0.28 0.26 0.46]
# predicted
# neutro [0.27 0.27 0.46]
# predicted
# neutro [0.28 0.27 0.45]
# predicted
# neutro [0.27 0.28 0.45]
# predicted
# neutro [0.28 0.23 0.49]
# predicted
# neutro [0.29 0.22 0.49]
# predicted
# neutro [0.29 0.22 0.49]
# predicted
# neutro [0.29 0.22 0.49]
# predicted
# neutro [0.3  0.21 0.49]
# predicted
# neutro [0.32 0.2  0.48]
# predicted
# neutro [0.33 0.2  0.47]
# predicted
# neutro [0.33 0.2  0.47]
# predicted
# neutro [0.31 0.21 0.48]
# predicted
# neutro [0.32 0.21 0.47]
# predicted
# neutro [0.31 0.23 0.46]
# predicted
# neutro [0.28 0.24 0.48]
# predicted
# neutro [0.24 0.26 0.5 ]
# predicted
# neutro [0.22 0.34 0.44]
# predicted
# neutro [0.24 0.31 0.45]
# predicted
# neutro [0.21 0.33 0.46]
# predicted
# neutro [0.19 0.33 0.48]
# predicted
# neutro [0.2  0.33 0.47]
# predicted
# neutro [0.23 0.3  0.47]
# predicted
# neutro [0.2  0.33 0.47]
# predicted
# neutro [0.2  0.35 0.45]
# predicted
# neutro [0.2  0.33 0.47]
# predicted
# neutro [0.24 0.19 0.57]
# predicted
# neutro [0.24 0.23 0.53]
# predicted
# neutro [0.27 0.17 0.56]
# predicted
# neutro [0.34 0.15 0.51]
# predicted
# neutro [0.37 0.11 0.52]
# predicted
# neutro [0.35 0.17 0.48]
# predicted
# neutro [0.35 0.2  0.45]
# predicted
# neutro [0.41 0.11 0.48]
# predicted
# neutro [0.4  0.11 0.49]
# predicted
# neutro [0.37 0.17 0.46]
# predicted
# neutro [0.37 0.1  0.53]
# predicted
# neutro [0.37 0.07 0.56]
# predicted
# neutro [0.39 0.06 0.55]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.41 0.04 0.55]
# predicted
# neutro [0.41 0.1  0.49]
# predicted
# neutro [0.39 0.13 0.48]
# predicted
# neutro [0.44 0.04 0.52]
# predicted
# neutro [0.41 0.1  0.49]
# predicted
# neutro [0.39 0.1  0.51]
# predicted
# neutro [0.39 0.1  0.51]
# predicted
# neutro [0.43 0.04 0.53]
# predicted
# neutro [0.45 0.03 0.52]
# predicted
# neutro [0.42 0.04 0.54]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.38 0.05 0.57]
# predicted
# neutro [0.38 0.05 0.57]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.41 0.05 0.54]
# predicted
# neutro [0.36 0.05 0.59]
# predicted
# neutro [0.39 0.04 0.57]
# predicted
# neutro [0.41 0.04 0.55]
# predicted
# neutro [0.41 0.04 0.55]
# predicted
# neutro [0.43 0.04 0.53]
# predicted
# neutro [0.42 0.04 0.54]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.36 0.1  0.54]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.4  0.05 0.55]
# predicted
# neutro [0.39 0.05 0.56]
# predicted
# neutro [0.39 0.04 0.57]
# predicted
# neutro [0.37 0.05 0.58]
# predicted
# neutro [0.37 0.06 0.57]
# predicted
# neutro [0.37 0.06 0.57]
# predicted
# neutro [0.37 0.05 0.58]
# predicted
# neutro [0.28 0.14 0.58]
# predicted
# neutro [0.26 0.14 0.6 ]
# predicted
# neutro [0.27 0.18 0.55]
# predicted
# neutro [0.24 0.23 0.53]
# predicted
# neutro [0.22 0.25 0.53]
# predicted
# neutro [0.2  0.28 0.52]
# predicted
# neutro [0.17 0.3  0.53]
# predicted
# neutro [0.19 0.32 0.49]
# predicted
# neutro [0.17 0.24 0.59]
# predicted
# neutro [0.17 0.24 0.59]
# predicted
# neutro [0.14 0.3  0.56]
# predicted
# neutro [0.15 0.29 0.56]
# predicted
# neutro [0.17 0.26 0.57]
# predicted
# neutro [0.17 0.26 0.57]
# predicted
# neutro [0.19 0.26 0.55]
# predicted
# neutro [0.17 0.26 0.57]
# predicted
# neutro [0.16 0.28 0.56]
# predicted
# neutro [0.16 0.28 0.56]
# predicted
# neutro [0.15 0.28 0.57]
# predicted
# neutro [0.15 0.28 0.57]
# predicted
# neutro [0.16 0.27 0.57]
# predicted
# neutro [0.18 0.26 0.56]
# predicted
# neutro [0.21 0.27 0.52]
# predicted
# neutro [0.22 0.27 0.51]
# predicted
# neutro [0.2  0.28 0.52]
# predicted
# neutro [0.23 0.26 0.51]
# predicted
# neutro [0.24 0.21 0.55]
# predicted
# neutro [0.24 0.18 0.58]
# predicted
# neutro [0.24 0.18 0.58]
# predicted
# neutro [0.22 0.17 0.61]
# predicted
# neutro [0.23 0.16 0.61]
# predicted
# neutro [0.2  0.15 0.65]
# predicted
# neutro [0.18 0.19 0.63]
# predicted
# neutro [0.18 0.19 0.63]
# predicted
# neutro [0.19 0.16 0.65]
# predicted
# neutro [0.18 0.19 0.63]
# predicted
# neutro [0.18 0.16 0.66]
# predicted
# neutro [0.2  0.21 0.59]
# predicted
# neutro [0.15 0.24 0.61]
# predicted
# neutro [0.14 0.25 0.61]
# predicted
# neutro [0.15 0.25 0.6 ]
# predicted
# neutro [0.14 0.24 0.62]
# predicted
# neutro [0.13 0.25 0.62]
# predicted
# neutro [0.13 0.26 0.61]
# predicted
# neutro [0.13 0.28 0.59]
# predicted
# neutro [0.12 0.35 0.53]
# predicted
# neutro [0.09 0.41 0.5 ]
# predicted
# neutro [0.08 0.42 0.5 ]
# predicted
# neutro [0.08 0.39 0.53]
# predicted
# neutro [0.09 0.39 0.52]
# predicted
# neutro [0.08 0.43 0.49]
# predicted
# neutro [0.09 0.41 0.5 ]
# predicted
# neutro [0.09 0.37 0.54]
# predicted
# neutro [0.09 0.38 0.53]
# predicted
# neutro [0.07 0.43 0.5 ]
# predicted
# izquierda [0.06 0.49 0.45]
# predicted
# izquierda [0.05 0.49 0.46]
# predicted
# izquierda [0.05 0.51 0.44]
# predicted
# izquierda [0.04 0.53 0.43]
# predicted
# izquierda [0.04 0.52 0.44]
# predicted
# izquierda [0.04 0.5  0.46]
# predicted
# neutro [0.05 0.47 0.48]
# predicted
# neutro [0.07 0.44 0.49]
# predicted
# neutro [0.06 0.44 0.5 ]
# predicted
# neutro [0.06 0.45 0.49]
# predicted
# izquierda [0.04 0.49 0.47]
# predicted
# izquierda [0.04 0.5  0.46]
# predicted
# izquierda [0.04 0.51 0.45]
# predicted
# izquierda [0.05 0.52 0.43]
# predicted
# izquierda [0.07 0.5  0.43]
# predicted
# izquierda [0.07 0.51 0.42]
# predicted
# izquierda [0.07 0.51 0.42]
# predicted
# izquierda [0.07 0.52 0.41]
# predicted
# izquierda [0.06 0.54 0.4 ]
# predicted
# izquierda [0.06 0.54 0.4 ]
# predicted
# izquierda [0.04 0.57 0.39]
# predicted
# izquierda [0.03 0.63 0.34]
# predicted
# izquierda [0.03 0.67 0.3 ]
# predicted
# izquierda [0.02 0.68 0.3 ]
# predicted
# izquierda [0.02 0.68 0.3 ]
# predicted
# izquierda [0.01 0.71 0.28]
# predicted
# izquierda [0.01 0.73 0.26]
# predicted
# izquierda [0.01 0.76 0.23]
# predicted
# izquierda [0.01 0.76 0.23]
# predicted
# izquierda [0.01 0.76 0.23]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.02 0.77 0.21]
# predicted
# izquierda [0.01 0.79 0.2 ]
# predicted
# izquierda [0.01 0.79 0.2 ]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.1 0.6 0.3]
# predicted
# izquierda [0.12 0.57 0.31]
# predicted
# izquierda [0.17 0.43 0.4 ]
# predicted
# neutro [0.2  0.34 0.46]
# predicted
# neutro [0.22 0.3  0.48]
# predicted
# neutro [0.26 0.3  0.44]
# predicted
# neutro [0.21 0.39 0.4 ]
# predicted
# neutro [0.28 0.23 0.49]
# predicted
# neutro [0.32 0.27 0.41]
# predicted
# neutro [0.37 0.2  0.43]
# predicted
# neutro [0.45 0.08 0.47]
# predicted
# neutro [0.45 0.08 0.47]
# predicted
# neutro [0.42 0.08 0.5 ]
# predicted
# derecha [0.47 0.09 0.44]
# predicted
# derecha [0.52 0.08 0.4 ]
# predicted
# derecha [0.58 0.08 0.34]
# predicted
# derecha [0.63 0.04 0.33]
# predicted
# derecha [0.66 0.02 0.32]
# predicted
# derecha [0.66 0.02 0.32]
# predicted
# derecha [0.66 0.02 0.32]
# predicted
# derecha [0.66 0.02 0.32]
# predicted
# derecha [0.65 0.03 0.32]
# predicted
# derecha [0.7  0.02 0.28]
# predicted
# derecha [0.71 0.02 0.27]
# predicted
# derecha [0.71 0.02 0.27]
# predicted
# derecha [0.73 0.01 0.26]
# predicted
# derecha [0.7  0.03 0.27]
# predicted
# derecha [0.7  0.03 0.27]
# predicted
# derecha [0.69 0.05 0.26]
# predicted
# derecha [0.69 0.05 0.26]
# predicted
# derecha [0.68 0.05 0.27]
# predicted
# derecha [0.68 0.05 0.27]
# predicted
# derecha [0.67 0.06 0.27]
# predicted
# derecha [0.67 0.06 0.27]
# predicted
# derecha [0.68 0.05 0.27]
# predicted
# derecha [0.68 0.04 0.28]
# predicted
# derecha [0.68 0.04 0.28]
# predicted
# derecha [0.68 0.04 0.28]
# predicted
# derecha [0.69 0.03 0.28]
# predicted
# derecha [0.63 0.05 0.32]
# predicted
# derecha [0.56 0.11 0.33]
# predicted
# derecha [0.54 0.12 0.34]
# predicted
# derecha [0.6  0.06 0.34]
# predicted
# derecha [0.51 0.09 0.4 ]
# predicted
# derecha [0.47 0.18 0.35]
# predicted
# neutro [0.41 0.14 0.45]
# predicted
# neutro [0.4  0.18 0.42]
# predicted
# neutro [0.38 0.2  0.42]
# predicted
# neutro [0.33 0.22 0.45]
# predicted
# neutro [0.33 0.2  0.47]
# predicted
# neutro [0.36 0.26 0.38]
# predicted
# neutro [0.33 0.27 0.4 ]
# predicted
# neutro [0.27 0.31 0.42]
# predicted
# neutro [0.22 0.3  0.48]
# predicted
# neutro [0.23 0.31 0.46]
# predicted
# izquierda [0.14 0.43 0.43]
# predicted
# neutro [0.13 0.42 0.45]
# predicted
# neutro [0.12 0.43 0.45]
# predicted
# izquierda [0.13 0.45 0.42]
# predicted
# izquierda [0.07 0.55 0.38]
# predicted
# izquierda [0.06 0.56 0.38]
# predicted
# izquierda [0.05 0.55 0.4 ]
# predicted
# izquierda [0.05 0.55 0.4 ]
# predicted
# izquierda [0.04 0.56 0.4 ]
# predicted
# izquierda [0.04 0.56 0.4 ]
# predicted
# izquierda [0.05 0.56 0.39]
# predicted
# izquierda [0.05 0.6  0.35]
# predicted
# izquierda [0.03 0.71 0.26]
# predicted
# izquierda [0.02 0.75 0.23]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.07 0.65 0.28]
# predicted
# izquierda [0.12 0.56 0.32]
# predicted
# neutro [0.18 0.35 0.47]
# predicted
# neutro [0.2  0.38 0.42]
# predicted
# izquierda [0.22 0.43 0.35]
# predicted
# izquierda [0.22 0.42 0.36]
# predicted
# neutro [0.28 0.29 0.43]
# predicted
# neutro [0.28 0.22 0.5 ]
# predicted
# neutro [0.34 0.11 0.55]
# predicted
# neutro [0.35 0.17 0.48]
# predicted
# neutro [0.41 0.09 0.5 ]
# predicted
# neutro [0.41 0.09 0.5 ]
# predicted
# derecha [0.46 0.09 0.45]
# predicted
# derecha [0.55 0.04 0.41]
# predicted
# derecha [0.56 0.03 0.41]
# predicted
# derecha [0.6  0.03 0.37]
# predicted
# derecha [0.6  0.04 0.36]
# predicted
# derecha [0.61 0.03 0.36]
# predicted
# derecha [0.62 0.02 0.36]
# predicted
# derecha [0.62 0.02 0.36]
# predicted
# derecha [0.63 0.02 0.35]
# predicted
# derecha [0.65 0.02 0.33]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.69 0.02 0.29]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.67 0.03 0.3 ]
# predicted
# derecha [0.67 0.04 0.29]
# predicted
# derecha [0.56 0.07 0.37]
# predicted
# derecha [0.54 0.09 0.37]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.53 0.06 0.41]
# predicted
# derecha [0.47 0.11 0.42]
# predicted
# derecha [0.47 0.1  0.43]
# predicted
# derecha [0.47 0.1  0.43]
# predicted
# neutro [0.43 0.11 0.46]
# predicted
# neutro [0.42 0.14 0.44]
# predicted
# derecha [0.4 0.2 0.4]
# predicted
# neutro [0.37 0.23 0.4 ]
# predicted
# neutro [0.34 0.21 0.45]
# predicted
# neutro [0.33 0.22 0.45]
# predicted
# neutro [0.32 0.23 0.45]
# predicted
# neutro [0.31 0.23 0.46]
# predicted
# neutro [0.31 0.28 0.41]
# predicted
# neutro [0.3  0.28 0.42]
# predicted
# neutro [0.2  0.39 0.41]
# predicted
# neutro [0.17 0.4  0.43]
# predicted
# izquierda [0.19 0.41 0.4 ]
# predicted
# neutro [0.24 0.3  0.46]
# predicted
# neutro [0.26 0.26 0.48]
# predicted
# neutro [0.21 0.32 0.47]
# predicted
# neutro [0.2  0.32 0.48]
# predicted
# neutro [0.18 0.36 0.46]
# predicted
# neutro [0.17 0.38 0.45]
# predicted
# neutro [0.18 0.37 0.45]
# predicted
# neutro [0.17 0.28 0.55]
# predicted
# neutro [0.18 0.27 0.55]
# predicted
# neutro [0.16 0.26 0.58]
# predicted
# neutro [0.15 0.3  0.55]
# predicted
# neutro [0.19 0.28 0.53]
# predicted
# neutro [0.17 0.27 0.56]
# predicted
# neutro [0.15 0.28 0.57]
# predicted
# neutro [0.15 0.3  0.55]
# predicted
# neutro [0.16 0.27 0.57]
# predicted
# neutro [0.16 0.22 0.62]
# predicted
# neutro [0.16 0.13 0.71]
# predicted
# neutro [0.16 0.11 0.73]
# predicted
# neutro [0.18 0.13 0.69]
# predicted
# neutro [0.2  0.13 0.67]
# predicted
# neutro [0.22 0.09 0.69]
# predicted
# neutro [0.22 0.08 0.7 ]
# predicted
# neutro [0.23 0.09 0.68]
# predicted
# neutro [0.23 0.07 0.7 ]
# predicted
# neutro [0.23 0.06 0.71]
# predicted
# neutro [0.27 0.09 0.64]
# predicted
# neutro [0.28 0.12 0.6 ]
# predicted
# neutro [0.29 0.12 0.59]
# predicted
# neutro [0.26 0.09 0.65]
# predicted
# neutro [0.26 0.08 0.66]
# predicted
# neutro [0.27 0.07 0.66]
# predicted
# neutro [0.24 0.1  0.66]
# predicted
# neutro [0.22 0.09 0.69]
# predicted
# neutro [0.22 0.1  0.68]
# predicted
# neutro [0.23 0.13 0.64]
# predicted
# neutro [0.22 0.16 0.62]
# predicted
# neutro [0.24 0.13 0.63]
# predicted
# neutro [0.22 0.16 0.62]
# predicted
# neutro [0.21 0.21 0.58]
# predicted
# neutro [0.16 0.24 0.6 ]
# predicted
# neutro [0.2  0.27 0.53]
# predicted
# neutro [0.17 0.29 0.54]
# predicted
# neutro [0.15 0.34 0.51]
# predicted
# izquierda [0.1  0.46 0.44]
# predicted
# izquierda [0.08 0.46 0.46]
# predicted
# neutro [0.09 0.44 0.47]
# predicted
# neutro [0.12 0.41 0.47]
# predicted
# neutro [0.14 0.35 0.51]
# predicted
# neutro [0.15 0.26 0.59]
# predicted
# neutro [0.14 0.26 0.6 ]
# predicted
# neutro [0.15 0.27 0.58]
# predicted
# neutro [0.15 0.28 0.57]
# predicted
# neutro [0.15 0.28 0.57]
# predicted
# neutro [0.13 0.33 0.54]
# predicted
# neutro [0.11 0.36 0.53]
# predicted
# neutro [0.11 0.36 0.53]
# predicted
# neutro [0.1  0.39 0.51]
# predicted
# neutro [0.08 0.43 0.49]
# predicted
# neutro [0.1  0.43 0.47]
# predicted
# neutro [0.09 0.44 0.47]
# predicted
# neutro [0.09 0.43 0.48]
# predicted
# neutro [0.15 0.37 0.48]
# predicted
# neutro [0.17 0.39 0.44]
# predicted
# izquierda [0.14 0.44 0.42]
# predicted
# neutro [0.14 0.42 0.44]
# predicted
# neutro [0.18 0.37 0.45]
# predicted
# neutro [0.19 0.3  0.51]
# predicted
# neutro [0.2  0.29 0.51]
# predicted
# neutro [0.22 0.29 0.49]
# predicted
# neutro [0.23 0.28 0.49]
# predicted
# neutro [0.21 0.24 0.55]
# predicted
# neutro [0.23 0.26 0.51]
# predicted
# neutro [0.2  0.22 0.58]
# predicted
# neutro [0.23 0.21 0.56]
# predicted
# neutro [0.2  0.14 0.66]
# predicted
# neutro [0.17 0.08 0.75]
# predicted
# neutro [0.19 0.14 0.67]
# predicted
# neutro [0.21 0.13 0.66]
# predicted
# neutro [0.21 0.15 0.64]
# predicted
# neutro [0.23 0.14 0.63]
# predicted
# neutro [0.24 0.12 0.64]
# predicted
# neutro [0.28 0.09 0.63]
# predicted
# neutro [0.29 0.08 0.63]
# predicted
# neutro [0.29 0.09 0.62]
# predicted
# neutro [0.3  0.05 0.65]
# predicted
# neutro [0.29 0.06 0.65]
# predicted
# neutro [0.29 0.04 0.67]
# predicted
# neutro [0.27 0.03 0.7 ]
# predicted
# neutro [0.18 0.1  0.72]
# predicted
# neutro [0.18 0.1  0.72]
# predicted
# neutro [0.24 0.13 0.63]
# predicted
# neutro [0.19 0.16 0.65]
# predicted
# neutro [0.19 0.16 0.65]
# predicted
# neutro [0.17 0.22 0.61]
# predicted
# neutro [0.15 0.24 0.61]
# predicted
# neutro [0.07 0.33 0.6 ]
# predicted
# neutro [0.06 0.36 0.58]
# predicted
# neutro [0.06 0.37 0.57]
# predicted
# neutro [0.05 0.39 0.56]
# predicted
# neutro [0.07 0.4  0.53]
# predicted
# neutro [0.07 0.42 0.51]
# predicted
# neutro [0.07 0.43 0.5 ]
# predicted
# izquierda [0.07 0.49 0.44]
# predicted
# izquierda [0.05 0.59 0.36]
# predicted
# izquierda [0.03 0.69 0.28]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.02 0.71 0.27]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.01 0.73 0.26]
# predicted
# izquierda [0.01 0.73 0.26]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.76 0.23]
# predicted
# izquierda [0.   0.78 0.22]
# predicted
# izquierda [0.07 0.68 0.25]
# predicted
# izquierda [0.08 0.69 0.23]
# predicted
# izquierda [0.17 0.55 0.28]
# predicted
# izquierda [0.17 0.52 0.31]
# predicted
# izquierda [0.2  0.41 0.39]
# predicted
# neutro [0.19 0.4  0.41]
# predicted
# neutro [0.2  0.39 0.41]
# predicted
# neutro [0.2  0.38 0.42]
# predicted
# neutro [0.2  0.38 0.42]
# predicted
# neutro [0.2  0.36 0.44]
# predicted
# neutro [0.18 0.34 0.48]
# predicted
# neutro [0.22 0.27 0.51]
# predicted
# neutro [0.24 0.27 0.49]
# predicted
# neutro [0.24 0.27 0.49]
# predicted
# neutro [0.24 0.27 0.49]
# predicted
# neutro [0.25 0.27 0.48]
# predicted
# neutro [0.25 0.27 0.48]
# predicted
# neutro [0.27 0.19 0.54]
# predicted
# neutro [0.27 0.18 0.55]
# predicted
# neutro [0.27 0.18 0.55]
# predicted
# neutro [0.27 0.18 0.55]
# predicted
# neutro [0.27 0.18 0.55]
# predicted
# neutro [0.29 0.15 0.56]
# predicted
# neutro [0.29 0.16 0.55]
# predicted
# neutro [0.29 0.17 0.54]
# predicted
# neutro [0.29 0.14 0.57]
# predicted
# neutro [0.16 0.31 0.53]
# predicted
# neutro [0.14 0.4  0.46]
# predicted
# izquierda [0.08 0.46 0.46]
# predicted
# izquierda [0.06 0.48 0.46]
# predicted
# izquierda [0.06 0.48 0.46]
# predicted
# izquierda [0.07 0.49 0.44]
# predicted
# izquierda [0.08 0.48 0.44]
# predicted
# izquierda [0.08 0.5  0.42]
# predicted
# izquierda [0.07 0.5  0.43]
# predicted
# izquierda [0.05 0.54 0.41]
# predicted
# izquierda [0.05 0.59 0.36]
# predicted
# izquierda [0.03 0.69 0.28]
# predicted
# izquierda [0.01 0.73 0.26]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.02 0.75 0.23]
# predicted
# izquierda [0.01 0.76 0.23]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.   0.77 0.23]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.78 0.21]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.   0.79 0.21]
# predicted
# izquierda [0.   0.79 0.21]
# predicted
# izquierda [0.12 0.64 0.24]
# predicted
# izquierda [0.18 0.56 0.26]
# predicted
# izquierda [0.23 0.39 0.38]
# predicted
# neutro [0.28 0.29 0.43]
# predicted
# neutro [0.35 0.21 0.44]
# predicted
# neutro [0.35 0.18 0.47]
# predicted
# neutro [0.36 0.19 0.45]
# predicted
# neutro [0.36 0.19 0.45]
# predicted
# neutro [0.3  0.24 0.46]
# predicted
# neutro [0.36 0.14 0.5 ]
# predicted
# neutro [0.36 0.14 0.5 ]
# predicted
# neutro [0.36 0.12 0.52]
# predicted
# neutro [0.39 0.11 0.5 ]
# predicted
# neutro [0.41 0.09 0.5 ]
# predicted
# neutro [0.38 0.1  0.52]
# predicted
# derecha [0.48 0.06 0.46]
# predicted
# derecha [0.5  0.07 0.43]
# predicted
# derecha [0.55 0.06 0.39]
# predicted
# derecha [0.58 0.05 0.37]
# predicted
# derecha [0.6  0.05 0.35]
# predicted
# derecha [0.6  0.04 0.36]
# predicted
# derecha [0.61 0.03 0.36]
# predicted
# derecha [0.66 0.03 0.31]
# predicted
# derecha [0.66 0.03 0.31]
# predicted
# derecha [0.65 0.03 0.32]
# predicted
# derecha [0.7  0.01 0.29]
# predicted
# derecha [0.69 0.01 0.3 ]
# predicted
# derecha [0.69 0.01 0.3 ]
# predicted
# derecha [0.69 0.01 0.3 ]
# predicted
# derecha [0.71 0.01 0.28]
# predicted
# derecha [0.71 0.01 0.28]
# predicted
# derecha [0.7  0.02 0.28]
# predicted
# derecha [0.69 0.02 0.29]
# predicted
# derecha [0.7  0.02 0.28]
# predicted
# derecha [0.68 0.02 0.3 ]
# predicted
# derecha [0.65 0.02 0.33]
# predicted
# derecha [0.62 0.02 0.36]
# predicted
# derecha [0.59 0.04 0.37]
# predicted
# derecha [0.58 0.04 0.38]
# predicted
# derecha [0.49 0.04 0.47]
# predicted
# derecha [0.51 0.03 0.46]
# predicted
# derecha [0.49 0.04 0.47]
# predicted
# derecha [0.49 0.03 0.48]
# predicted
# derecha [0.48 0.04 0.48]
# predicted
# derecha [0.48 0.05 0.47]
# predicted
# derecha [0.48 0.05 0.47]
# predicted
# neutro [0.46 0.05 0.49]
# predicted
# neutro [0.44 0.06 0.5 ]
# predicted
# neutro [0.38 0.14 0.48]
# predicted
# neutro [0.35 0.16 0.49]
# predicted
# neutro [0.34 0.21 0.45]
# predicted
# neutro [0.32 0.25 0.43]
# predicted
# neutro [0.31 0.27 0.42]
# predicted
# neutro [0.28 0.21 0.51]
# predicted
# neutro [0.25 0.27 0.48]
# predicted
# neutro [0.26 0.27 0.47]
# predicted
# neutro [0.26 0.28 0.46]
# predicted
# neutro [0.27 0.27 0.46]
# predicted
# neutro [0.27 0.27 0.46]
# predicted
# neutro [0.27 0.27 0.46]
# predicted
# neutro [0.28 0.26 0.46]
# predicted
# neutro [0.32 0.24 0.44]
# predicted
# neutro [0.31 0.21 0.48]
# predicted
# derecha [0.38 0.25 0.37]
# predicted
# neutro [0.41 0.1  0.49]
# predicted
# neutro [0.42 0.08 0.5 ]
# predicted
# neutro [0.34 0.04 0.62]
# predicted
# neutro [0.34 0.08 0.58]
# predicted
# neutro [0.31 0.07 0.62]
# predicted
# neutro [0.36 0.06 0.58]
# predicted
# neutro [0.37 0.06 0.57]
# predicted
# neutro [0.42 0.04 0.54]
# predicted
# neutro [0.43 0.03 0.54]
# predicted
# neutro [0.43 0.04 0.53]
# predicted
# neutro [0.46 0.03 0.51]
# predicted
# neutro [0.46 0.03 0.51]
# predicted
# neutro [0.46 0.03 0.51]
# predicted
# derecha [0.49 0.04 0.47]
# predicted
# derecha [0.56 0.05 0.39]
# predicted
# derecha [0.63 0.05 0.32]
# predicted
# derecha [0.64 0.02 0.34]
# predicted
# derecha [0.65 0.02 0.33]
# predicted
# derecha [0.6  0.06 0.34]
# predicted
# derecha [0.57 0.03 0.4 ]
# predicted
# derecha [0.56 0.03 0.41]
# predicted
# derecha [0.54 0.02 0.44]
# predicted
# neutro [0.47 0.05 0.48]
# predicted
# derecha [0.49 0.03 0.48]
# predicted
# neutro [0.46 0.04 0.5 ]
# predicted
# neutro [0.45 0.05 0.5 ]
# predicted
# neutro [0.35 0.07 0.58]
# predicted
# neutro [0.39 0.07 0.54]
# predicted
# neutro [0.36 0.13 0.51]
# predicted
# neutro [0.22 0.26 0.52]
# predicted
# neutro [0.15 0.33 0.52]
# predicted
# neutro [0.13 0.38 0.49]
# predicted
# neutro [0.15 0.42 0.43]
# predicted
# izquierda [0.09 0.52 0.39]
# predicted
# izquierda [0.07 0.5  0.43]
# predicted
# izquierda [0.06 0.53 0.41]
# predicted
# izquierda [0.06 0.53 0.41]
# predicted
# izquierda [0.05 0.54 0.41]
# predicted
# izquierda [0.05 0.54 0.41]
# predicted
# izquierda [0.05 0.54 0.41]
# predicted
# izquierda [0.06 0.57 0.37]
# predicted
# izquierda [0.05 0.63 0.32]
# predicted
# izquierda [0.02 0.72 0.26]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.01 0.74 0.25]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.77 0.22]
# predicted
# izquierda [0.02 0.75 0.23]
# predicted
# izquierda [0.03 0.74 0.23]
# predicted
# izquierda [0.02 0.75 0.23]
# predicted
# izquierda [0.12 0.57 0.31]
# predicted
# izquierda [0.18 0.42 0.4 ]
# predicted
# neutro [0.17 0.4  0.43]
# predicted
# neutro [0.21 0.36 0.43]
# predicted
# neutro [0.25 0.32 0.43]
# predicted
# neutro [0.33 0.23 0.44]
# predicted
# neutro [0.37 0.2  0.43]
# predicted
# neutro [0.37 0.19 0.44]
# predicted
# neutro [0.4  0.16 0.44]
# predicted
# derecha [0.44 0.13 0.43]
# predicted
# derecha [0.46 0.13 0.41]
# predicted
# derecha [0.52 0.06 0.42]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.54 0.06 0.4 ]
# predicted
# derecha [0.54 0.06 0.4 ]
# predicted
# derecha [0.55 0.06 0.39]
# predicted
# derecha [0.56 0.05 0.39]
# predicted
# derecha [0.63 0.04 0.33]
# predicted
# derecha [0.64 0.05 0.31]
# predicted
# derecha [0.65 0.05 0.3 ]
# predicted
# derecha [0.61 0.06 0.33]
# predicted
# derecha [0.51 0.08 0.41]
# predicted
# neutro [0.43 0.1  0.47]
# predicted
# derecha [0.42 0.18 0.4 ]
# predicted
# neutro [0.37 0.24 0.39]
# predicted
# neutro [0.29 0.23 0.48]
# predicted
# neutro [0.25 0.26 0.49]
# predicted
# neutro [0.25 0.28 0.47]
# predicted
# neutro [0.11 0.41 0.48]
# predicted
# neutro [0.1  0.42 0.48]
# predicted
# neutro [0.09 0.44 0.47]
# predicted
# izquierda [0.07 0.56 0.37]
# predicted
# izquierda [0.07 0.58 0.35]
# predicted
# izquierda [0.06 0.54 0.4 ]
# predicted
# izquierda [0.06 0.56 0.38]
# predicted
# izquierda [0.05 0.58 0.37]
# predicted
# izquierda [0.05 0.58 0.37]
# predicted
# izquierda [0.06 0.54 0.4 ]
# predicted
# izquierda [0.07 0.56 0.37]
# predicted
# izquierda [0.07 0.57 0.36]
# predicted
# izquierda [0.03 0.66 0.31]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.01 0.72 0.27]
# predicted
# izquierda [0.01 0.72 0.27]
# predicted
# izquierda [0.01 0.72 0.27]
# predicted
# izquierda [0.   0.74 0.26]
# predicted
# izquierda [0.03 0.74 0.23]
# predicted
# izquierda [0.05 0.71 0.24]
# predicted
# izquierda [0.16 0.49 0.35]
# predicted
# neutro [0.2  0.39 0.41]
# predicted
# izquierda [0.23 0.41 0.36]
# predicted
# izquierda [0.22 0.46 0.32]
# predicted
# izquierda [0.23 0.43 0.34]
# predicted
# neutro [0.21 0.35 0.44]
# predicted
# neutro [0.23 0.37 0.4 ]
# predicted
# neutro [0.25 0.3  0.45]
# predicted
# neutro [0.29 0.2  0.51]
# predicted
# neutro [0.39 0.07 0.54]
# predicted
# neutro [0.4  0.07 0.53]
# predicted
# neutro [0.42 0.07 0.51]
# predicted
# neutro [0.44 0.07 0.49]
# predicted
# derecha [0.51 0.06 0.43]
# predicted
# derecha [0.51 0.06 0.43]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.52 0.06 0.42]
# predicted
# derecha [0.54 0.05 0.41]
# predicted
# derecha [0.53 0.04 0.43]
# predicted
# derecha [0.53 0.04 0.43]
# predicted
# derecha [0.53 0.04 0.43]
# predicted
# derecha [0.53 0.04 0.43]
# predicted
# derecha [0.53 0.04 0.43]
# predicted
# derecha [0.53 0.05 0.42]
# predicted
# derecha [0.54 0.04 0.42]
# predicted
# derecha [0.59 0.04 0.37]
# predicted
# derecha [0.59 0.04 0.37]
# predicted
# derecha [0.59 0.05 0.36]
# predicted
# derecha [0.58 0.05 0.37]
# predicted
# derecha [0.53 0.06 0.41]
# predicted
# derecha [0.48 0.06 0.46]
# predicted
# derecha [0.52 0.06 0.42]
# predicted
# derecha [0.52 0.07 0.41]
# predicted
# derecha [0.56 0.05 0.39]
# predicted
# derecha [0.47 0.06 0.47]
# predicted
# neutro [0.42 0.12 0.46]
# predicted
# neutro [0.36 0.14 0.5 ]
# predicted
# neutro [0.32 0.13 0.55]
# predicted
# neutro [0.31 0.12 0.57]
# predicted
# neutro [0.23 0.18 0.59]
# predicted
# neutro [0.24 0.19 0.57]
# predicted
# neutro [0.24 0.19 0.57]
# predicted
# neutro [0.2  0.23 0.57]
# predicted
# neutro [0.18 0.31 0.51]
# predicted
# neutro [0.18 0.32 0.5 ]
# predicted
# neutro [0.18 0.32 0.5 ]
# predicted
# neutro [0.17 0.32 0.51]
# predicted
# neutro [0.19 0.31 0.5 ]
# predicted
# neutro [0.17 0.27 0.56]
# predicted
# neutro [0.22 0.22 0.56]
# predicted
# neutro [0.22 0.22 0.56]
# predicted
# neutro [0.2  0.23 0.57]
# predicted
# neutro [0.21 0.23 0.56]
# predicted
# neutro [0.16 0.29 0.55]
# predicted
# neutro [0.16 0.31 0.53]
# predicted
# neutro [0.15 0.32 0.53]
# predicted
# neutro [0.14 0.27 0.59]
# predicted
# neutro [0.13 0.25 0.62]
# predicted
# neutro [0.08 0.23 0.69]
# predicted
# neutro [0.1  0.25 0.65]
# predicted
# neutro [0.11 0.24 0.65]
# predicted
# neutro [0.09 0.26 0.65]
# predicted
# neutro [0.07 0.35 0.58]
# predicted
# neutro [0.05 0.4  0.55]
# predicted
# neutro [0.04 0.42 0.54]
# predicted
# neutro [0.04 0.42 0.54]
# predicted
# neutro [0.05 0.42 0.53]
# predicted
# neutro [0.03 0.42 0.55]
# predicted
# neutro [0.04 0.42 0.54]
# predicted
# neutro [0.04 0.42 0.54]
# predicted
# neutro [0.04 0.43 0.53]
# predicted
# neutro [0.04 0.43 0.53]
# predicted
# neutro [0.04 0.44 0.52]
# predicted
# izquierda [0.05 0.48 0.47]
# predicted
# izquierda [0.05 0.5  0.45]
# predicted
# izquierda [0.05 0.53 0.42]
# predicted
# izquierda [0.05 0.56 0.39]
# predicted
# izquierda [0.04 0.58 0.38]
# predicted
# izquierda [0.03 0.63 0.34]
# predicted
# izquierda [0.03 0.65 0.32]
# predicted
# izquierda [0.02 0.71 0.27]
# predicted
# izquierda [0.02 0.71 0.27]
# predicted
# izquierda [0.02 0.72 0.26]
# predicted
# izquierda [0.12 0.6  0.28]
# predicted
# izquierda [0.14 0.55 0.31]
# predicted
# izquierda [0.18 0.42 0.4 ]
# predicted
# neutro [0.15 0.42 0.43]
# predicted
# neutro [0.13 0.41 0.46]
# predicted
# neutro [0.12 0.42 0.46]
# predicted
# neutro [0.13 0.41 0.46]
# predicted
# neutro [0.13 0.42 0.45]
# predicted
# neutro [0.14 0.38 0.48]
# predicted
# neutro [0.16 0.36 0.48]
# predicted
# neutro [0.15 0.36 0.49]
# predicted
# neutro [0.21 0.29 0.5 ]
# predicted
# neutro [0.2  0.29 0.51]
# predicted
# neutro [0.18 0.26 0.56]
# predicted
# neutro [0.17 0.33 0.5 ]
# predicted
# neutro [0.17 0.34 0.49]
# predicted
# neutro [0.22 0.13 0.65]
# predicted
# neutro [0.19 0.09 0.72]
# predicted
# neutro [0.18 0.1  0.72]
# predicted
# neutro [0.19 0.12 0.69]
# predicted
# neutro [0.2  0.06 0.74]
# predicted
# neutro [0.21 0.08 0.71]
# predicted
# neutro [0.23 0.11 0.66]
# predicted
# neutro [0.24 0.13 0.63]
# predicted
# neutro [0.27 0.12 0.61]
# predicted
# neutro [0.29 0.1  0.61]
# predicted
# neutro [0.29 0.1  0.61]
# predicted
# neutro [0.28 0.1  0.62]
# predicted
# neutro [0.3  0.03 0.67]
# predicted
# neutro [0.31 0.08 0.61]
# predicted
# neutro [0.3  0.11 0.59]
# predicted
# neutro [0.29 0.09 0.62]
# predicted
# neutro [0.28 0.1  0.62]
# predicted
# neutro [0.29 0.11 0.6 ]
# predicted
# neutro [0.3  0.07 0.63]
# predicted
# neutro [0.31 0.04 0.65]
# predicted
# neutro [0.23 0.04 0.73]
# predicted
# neutro [0.21 0.06 0.73]
# predicted
# neutro [0.24 0.05 0.71]
# predicted
# neutro [0.14 0.23 0.63]
# predicted
# neutro [0.14 0.21 0.65]
# predicted
# neutro [0.12 0.3  0.58]
# predicted
# neutro [0.06 0.39 0.55]
# predicted
# neutro [0.08 0.41 0.51]
# predicted
# izquierda [0.06 0.49 0.45]
# predicted
# izquierda [0.05 0.51 0.44]
# predicted
# izquierda [0.05 0.51 0.44]
# predicted
# izquierda [0.05 0.52 0.43]
# predicted
# izquierda [0.05 0.55 0.4 ]
# predicted
# izquierda [0.05 0.61 0.34]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.02 0.7  0.28]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.01 0.75 0.24]
# predicted
# izquierda [0.02 0.78 0.2 ]
# predicted
# izquierda [0.02 0.78 0.2 ]
# predicted
# izquierda [0.02 0.77 0.21]
# predicted
# izquierda [0.03 0.76 0.21]
# predicted
# izquierda [0.04 0.75 0.21]
# predicted
# izquierda [0.01 0.79 0.2 ]
# predicted
# izquierda [0.11 0.59 0.3 ]
# predicted
# izquierda [0.18 0.46 0.36]
# predicted
# neutro [0.19 0.38 0.43]
# predicted
# neutro [0.16 0.4  0.44]
# predicted
# neutro [0.14 0.38 0.48]
# predicted
# neutro [0.12 0.37 0.51]
# predicted
# neutro [0.14 0.36 0.5 ]
# predicted
# neutro [0.17 0.3  0.53]
# predicted
# neutro [0.22 0.17 0.61]
# predicted
# neutro [0.18 0.25 0.57]
# predicted
# neutro [0.21 0.15 0.64]
# predicted
# neutro [0.16 0.09 0.75]
# predicted
# neutro [0.19 0.12 0.69]
# predicted
# neutro [0.2  0.09 0.71]
# predicted
# neutro [0.2  0.14 0.66]
# predicted
# neutro [0.23 0.13 0.64]
# predicted
# neutro [0.22 0.12 0.66]
# predicted
# neutro [0.2  0.09 0.71]
# predicted
# neutro [0.2  0.07 0.73]
# predicted
# neutro [0.2  0.08 0.72]
# predicted
# neutro [0.19 0.08 0.73]
# predicted
# neutro [0.19 0.08 0.73]
# predicted
# neutro [0.2  0.06 0.74]
# predicted
# neutro [0.19 0.06 0.75]
# predicted
# neutro [0.17 0.07 0.76]
# predicted
# neutro [0.18 0.07 0.75]
# predicted
# neutro [0.15 0.05 0.8 ]
# predicted
# neutro [0.18 0.05 0.77]
# predicted
# neutro [0.2  0.04 0.76]
# predicted
# neutro [0.19 0.03 0.78]
# predicted
# neutro [0.2  0.03 0.77]
# predicted
# neutro [0.23 0.08 0.69]
# predicted
# neutro [0.23 0.09 0.68]
# predicted
# neutro [0.24 0.09 0.67]
# predicted
# neutro [0.24 0.06 0.7 ]
# predicted
# neutro [0.25 0.07 0.68]
# predicted
# neutro [0.21 0.06 0.73]
# predicted
# neutro [0.22 0.11 0.67]
# predicted
# neutro [0.2  0.11 0.69]
# predicted
# neutro [0.18 0.1  0.72]
# predicted
# neutro [0.19 0.05 0.76]
# predicted
# neutro [0.17 0.04 0.79]
# predicted
# neutro [0.19 0.11 0.7 ]
# predicted
# neutro [0.18 0.04 0.78]
# predicted
# neutro [0.17 0.04 0.79]
# predicted
# neutro [0.19 0.05 0.76]
# predicted
# neutro [0.2  0.06 0.74]
# predicted
# neutro [0.19 0.1  0.71]
# predicted
# neutro [0.19 0.1  0.71]
# predicted
# neutro [0.18 0.13 0.69]
# predicted
# neutro [0.18 0.13 0.69]
# predicted
# neutro [0.16 0.14 0.7 ]
# predicted
# neutro [0.15 0.13 0.72]
# predicted
# neutro [0.16 0.12 0.72]
# predicted
# neutro [0.2  0.12 0.68]
# predicted
# neutro [0.21 0.13 0.66]
# predicted
# neutro [0.21 0.11 0.68]
# predicted
# neutro [0.26 0.12 0.62]
# predicted
# neutro [0.25 0.12 0.63]
# predicted
# neutro [0.32 0.13 0.55]
# predicted
# neutro [0.32 0.1  0.58]
# predicted
# neutro [0.38 0.09 0.53]
# predicted
# neutro [0.44 0.09 0.47]
# predicted
# derecha [0.45 0.1  0.45]
# predicted
# derecha [0.46 0.1  0.44]
# predicted
# derecha [0.47 0.1  0.43]
# predicted
# derecha [0.47 0.1  0.43]
# predicted
# derecha [0.46 0.1  0.44]
# predicted
# neutro [0.42 0.11 0.47]
# predicted
# neutro [0.33 0.14 0.53]
# predicted
# neutro [0.3  0.13 0.57]
# predicted
# neutro [0.3  0.16 0.54]
# predicted
# neutro [0.3  0.17 0.53]
# predicted
# neutro [0.28 0.18 0.54]
# predicted
# neutro [0.28 0.19 0.53]
# predicted
# neutro [0.28 0.19 0.53]
# predicted
# neutro [0.3 0.2 0.5]
# predicted
# neutro [0.29 0.2  0.51]
# predicted
# neutro [0.29 0.21 0.5 ]
# predicted
# neutro [0.29 0.21 0.5 ]
# predicted
# neutro [0.28 0.2  0.52]
# predicted
# neutro [0.26 0.19 0.55]
# predicted
# neutro [0.28 0.17 0.55]
# predicted
# neutro [0.29 0.18 0.53]
# predicted
# neutro [0.29 0.19 0.52]
# predicted
# neutro [0.29 0.18 0.53]
# predicted
# neutro [0.29 0.19 0.52]
# predicted
# neutro [0.28 0.21 0.51]
# predicted
# neutro [0.26 0.21 0.53]
# predicted
# neutro [0.26 0.21 0.53]
# predicted
# neutro [0.26 0.21 0.53]
# predicted
# neutro [0.25 0.21 0.54]
# predicted
# neutro [0.3  0.22 0.48]
# predicted
# neutro [0.3  0.22 0.48]
# predicted
# neutro [0.33 0.21 0.46]
# predicted
# neutro [0.37 0.2  0.43]
# predicted
# neutro [0.38 0.18 0.44]
# predicted
# derecha [0.44 0.13 0.43]
# predicted
# derecha [0.49 0.13 0.38]
# predicted
# derecha [0.5 0.1 0.4]
# predicted
# derecha [0.51 0.08 0.41]
# predicted
# derecha [0.5  0.08 0.42]
# predicted
# derecha [0.5  0.08 0.42]
# predicted
# derecha [0.5  0.08 0.42]
# predicted

# %%
# PRUEBA DE CAMARA
cap = cv2.VideoCapture(0)

# Curl counter variables
counter = 0 
current_stage = None

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        
        # Extract landmarks
        try:
                       
            # obtener el estado del box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Mostrar las clases
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
                        
            # Mostrar Probabilidad
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, '10.05'
                       , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                        
            # Mostrar Conteo
            cv2.putText(image, 'COUNT'
                        , (180,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            
        except Exception as e:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
